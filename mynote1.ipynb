# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# My name is <strong>AKINTOLA TOPE AKINFOLARIN</strong>
#
# I would love to become a data scientist to be able to work with data and improve the experience of users on the internet with well structured built websites

# %% [markdown]
# <i>I am interested in data science because I want to work with data to help improve the lives of people, Data can be a significant tool in placing the correct information and tools for the user at the right place at the right time while still protecting the user from unwanted misinformation, for instance giving them the right and most efficient route to work or pointing them to the location for groceries in the stores, all this can be done with data and thus why my interest in data has been my major driving force to learn and understand how to use data for the greater good.</i>

# %% [markdown]
# <h3>The code below shows how to add two strings Together to form a fullname</h3>

# %%
first_name = "fola"
last_name = " Akintola"
print(first_name + last_name)
# Out:
# fola Akintola

# %% [markdown]
# <ol>
# <li>Html/css</li>
# <li>javascript</li>
# <li>php</li>
# </ol>
#
# <ul>
# <li>voting app</li>
# <li>football game</li>
# </ul>
#
# <a href="https://dataplatform.cloud.ibm.com/gallery">IBM Cloud Gallery</a>
#
# <img src="https://www.icos-cp.eu/sites/default/files/inline-images/800px-Jupyter_logo.svg__0.png" width="300" alt="cognitiveclass.ai logo"  />
